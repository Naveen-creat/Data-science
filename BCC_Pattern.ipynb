# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveen-creat/Data-science/blob/main/BCC_Pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Import libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# Load the data

# %%
 pd.read_csv('/content/drive/MyDrive/Bank Customer Churn Prediction.csv')
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %% [markdown]
# Drop customer_id as it's not predictive

# %%
df = pd.read_csv('/content/drive/MyDrive/Bank Customer Churn Prediction.csv')

# %%
df = df.drop('customer_id', axis=1)

# %% [markdown]
# Encode categorical variables

# %%
label_encoders = {}
for col in ['country', 'gender']:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %% [markdown]
# Split data into features and target

# %%
X = df.drop('churn', axis=1)
y = df['churn']

# %% [markdown]
#  Scale features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Split data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %% [markdown]
# Train Random Forest Classifier

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# Make predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Evaluate the model

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      2416
#            1       0.78      0.46      0.58       584
#
#     accuracy                           0.87      3000
#    macro avg       0.83      0.71      0.75      3000
# weighted avg       0.86      0.87      0.86      3000
#
# Confusion Matrix:
#  [[2339   77]
#  [ 316  268]]
